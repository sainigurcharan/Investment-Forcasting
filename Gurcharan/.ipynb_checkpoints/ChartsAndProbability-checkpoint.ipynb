# %%
import pandas as pd

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image  
import PIL

# %%
chart_data = pd.read_csv(f"AllDataProbability.csv")

# %%
chart_data
# Out:
#           Date  Target_FR12Mts  LR_Up_Prob  LR_Down_Prob  RF1_Up_Prob  \
# 0     2/1/1999            0.11        0.75          0.25         0.59
# 1     2/1/1999            0.11        0.72          0.36         0.43
# 2     3/1/1999            0.17        0.59          0.31         0.58
# 3     3/1/1999            0.17        0.50          0.47         0.44
# 4     5/1/1999            0.10        0.54          0.40         0.47
# ..         ...             ...         ...           ...          ...
# 214   6/1/2018            0.08        0.48          0.00         0.39
# 215   7/1/2018            0.06        0.25          0.01         0.09
# 216   8/1/2018            0.01        0.30          0.00         0.17
# 217  10/1/2018            0.12        0.51          0.02         0.58
# 218  11/1/2018            0.14        0.51          0.04         0.43
#
#      RF1_Down_Prob  RF2_Up_Prob  RF2_Down_Prob  Avg_Up_3  Avg_Down_3  \
# ...

# %%
lr_up = sns.relplot(x="LR_Up_Prob", y="Target_FR12Mts", 
            sizes=(400, 4000), alpha=1, palette="muted",
            height=6, data=chart_data)
plt.title("Logistics Regression / Forward 12M Returns > 8%")
plt.axhline(0.08, color="green", linestyle="--")
plt.axhline(0.00, color="red", linestyle="--")
plt.axvline(0.5, color="red", linestyle="--")
plt.axvline(0.75, color="green", linestyle="--")

# plt.show(lr_up)
plt.savefig('lr_up.jpg')
plt.savefig('lr_up.jpg', bbox_inches='tight')

# %%
lr_down = sns.relplot(x="LR_Down_Prob", y="Target_FR12Mts", 
            sizes=(400, 4000), alpha=1, palette="muted",
            height=6, data=chart_data)
plt.title("Logistics Regression / Forward 12M Returns < 0%")

plt.axhline(0.00, color="red", linestyle="--")
plt.axvline(0.5, color="red", linestyle="--")
plt.axvline(0.75, color="green", linestyle="--")

# plt.show(lr_down)
plt.savefig('lr_down.jpg')
plt.savefig('lr_down.jpg', bbox_inches='tight')

# %%
rf1_up = sns.relplot(x="RF1_Up_Prob", y="Target_FR12Mts", 
            sizes=(400, 4000), alpha=1, palette="muted",
            height=6, data=chart_data)
plt.title("RandomForest1 / Forward 12M Returns > 8%")
plt.axhline(0.08, color="green", linestyle="--")
plt.axhline(0.00, color="red", linestyle="--")
plt.axvline(0.5, color="red", linestyle="--")
plt.axvline(0.75, color="green", linestyle="--")

# plt.show(rf1_up)

plt.savefig('rf1_up.jpg')
plt.savefig('rf1_up.jpg', bbox_inches='tight')

# %%
RF1_down = sns.relplot(x="RF1_Down_Prob", y="Target_FR12Mts", 
            sizes=(400, 4000), alpha=1, palette="muted",
            height=6, data=chart_data)
plt.title("RandomForest1 / Forward 12M Returns < 0%")

plt.axhline(0.00, color="red", linestyle="--")
plt.axvline(0.5, color="red", linestyle="--")
plt.axvline(0.75, color="green", linestyle="--")

# plt.show(RF1_down)

plt.savefig('rf1_down.jpg')
plt.savefig('rf1_down.jpg', bbox_inches='tight')

# %%
Rf2_up = sns.relplot(x="RF2_Up_Prob", y="Target_FR12Mts", 
            sizes=(400, 4000), alpha=1, palette="muted",
            height=6, data=chart_data)
plt.title("RandomForest2 / Forward 12M Returns > 8%")
plt.axhline(0.08, color="green", linestyle="--")
plt.axhline(0.00, color="red", linestyle="--")
plt.axvline(0.5, color="red", linestyle="--")
plt.axvline(0.75, color="green", linestyle="--")

# plt.show(Rf2_up)
plt.savefig('Rf2_up.jpg')
plt.savefig('Rf2_up.jpg', bbox_inches='tight')

# %%
RF2_down = sns.relplot(x="RF2_Down_Prob", y="Target_FR12Mts", 
            sizes=(400, 4000), alpha=1, palette="muted",
            height=6, data=chart_data)
plt.title("RandomForest2 / Forward 12M Returns < 0%")

plt.axhline(0.00, color="red", linestyle="--")
plt.axvline(0.5, color="red", linestyle="--")
plt.axvline(0.75, color="green", linestyle="--")

# plt.show(RF2_down)
plt.savefig('Rf2_down.jpg')
plt.savefig('Rf2_down.jpg', bbox_inches='tight')

# %%
bothrf_up = sns.relplot(x="Avg_Up_2", y="Target_FR12Mts", 
            sizes=(400, 4000), alpha=1, palette="muted",
            height=6, data=chart_data)
plt.title("2RF-models / Forward 12M Returns > 8%")
plt.axhline(0.08, color="green", linestyle="--")
plt.axhline(0.00, color="red", linestyle="--")
plt.axvline(0.5, color="red", linestyle="--")
plt.axvline(0.75, color="green", linestyle="--")

plt.show(bothrf_up)

# %%
bothrf_down = sns.relplot(x="Avg_Down_2", y="Target_FR12Mts", 
            sizes=(400, 4000), alpha=1, palette="muted",
            height=6, data=chart_data)
plt.title("2RF-models / Forward 12M Returns < 0%")

plt.axhline(0.00, color="red", linestyle="--")
plt.axvline(0.5, color="red", linestyle="--")
plt.axvline(0.75, color="green", linestyle="--")

plt.show(bothrf_down)

# %%
# from matplotlib.colors import ListedColormap
# flatui = ["#e74c3c", "#34495e","#95a5a6","#2ecc71","#9b59b6", "#3498db", ]          
# my_cmap = ListedColormap(sns.color_palette(flatui).as_hex())
# y = chart_data['Avg_Down_2']
# x = chart_data['Avg_Up_2']
# z = chart_data['Target_FR12Mts']
# colors = chart_data['Target_FR12Mts']
# # Plot
# plt.figure(figsize=(12, 5))
# sc = plt.scatter(x, y, c=colors, cmap=my_cmap)
                 
# plt.title('RFModels vs. 12MonthReturn')
# plt.xlabel('Avg Up2 Models')
# plt.ylabel('Avg Down2 Models')
# plt.axhline(0.47, color="blue", linestyle="--")
# plt.axvline(0.35, color="blue", linestyle="--")

# plt.axhline(0.5, color="red", linestyle="--")
# plt.axvline(0.5, color="red", linestyle="--")
# plt.colorbar(sc)
# # plt.show()

# plt.savefig('Rf_All4.jpg')
# plt.savefig('Rf_All4.jpg', bbox_inches='tight')

# %%
# from matplotlib.colors import ListedColormap
# flatui = ["#e74c3c", "#34495e","#95a5a6","#2ecc71","#9b59b6", "#3498db", ]          
# my_cmap = ListedColormap(sns.color_palette(flatui).as_hex())
# y = chart_data['RF1_Down_Prob']
# x = chart_data['RF2_Down_Prob']
# z = chart_data['Target_FR12Mts']
# colors = chart_data['Target_FR12Mts']
# # Plot
# plt.figure(figsize=(12, 5))
# sc = plt.scatter(x, y, c=colors, cmap=my_cmap)
                 
# plt.title('RFModels vs. 12MonthReturn')
# plt.xlabel('RF2_Down_Prob')
# plt.ylabel('RF1_Down_Prob')
# plt.axhline(0.42, color="blue", linestyle="--")
# plt.axvline(0.79, color="blue", linestyle="--")

# plt.axhline(0.5, color="red", linestyle="--")
# plt.axvline(0.5, color="red", linestyle="--")
# plt.colorbar(sc)
# # plt.show()

# plt.savefig('Rf_Both_Down.jpg')
# plt.savefig('Rf_Both_Down.jpg', bbox_inches='tight')

# %%
from matplotlib.colors import ListedColormap
flatui = ["#e74c3c", "#34495e","#95a5a6","#2ecc71","#9b59b6", "#3498db", ]          
my_cmap = ListedColormap(sns.color_palette(flatui).as_hex())
y = chart_data['RF1_Up_Prob']
x = chart_data['RF2_Up_Prob']
z = chart_data['Target_FR12Mts']
colors = chart_data['Target_FR12Mts']
# Plot
plt.figure(figsize=(12, 5))
sc = plt.scatter(x, y, c=colors, cmap=my_cmap)
                 
plt.title('RFModels vs. 12MonthReturn')
plt.xlabel('RF2_Up_Prob')
plt.ylabel('RF1_Up_Prob')
plt.axhline(0.26, color="blue", linestyle="--")
plt.axvline(0.43, color="blue", linestyle="--")

plt.axhline(0.5, color="red", linestyle="--")
plt.axvline(0.5, color="red", linestyle="--")
plt.colorbar(sc)
# plt.show()

plt.savefig('Rf_Both_Up.jpg')
plt.savefig('Rf_Both_Up.jpg', bbox_inches='tight')
