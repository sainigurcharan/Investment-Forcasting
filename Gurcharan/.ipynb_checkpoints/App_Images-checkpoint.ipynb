# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.style as style
style.use('fivethirtyeight')
# %matplotlib inline

# %%
df = pd.read_excel('data/RF_GS_UP_HistoricalResults.xlsx')
df.head()
# Out:
#    Unnamed: 0       Date  Target_FR12Mts  Prob
# 0         179 2013-11-01            0.14   1.0
# 1          45 2002-09-01            0.22   1.0
# 2         172 2013-04-01            0.18   1.0
# 3         171 2013-03-01            0.19   1.0
# 4         170 2013-02-01            0.23   1.0

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
sns.regplot(x=df["Target_FR12Mts"], y=df["Prob"], fit_reg=False, scatter_kws={"color":"green","alpha":0.3,"s":200})

# %%
plt.savefig('../Final_App/static/img/portfolio/img.jpg')
